# %%
import pandas as pd
import requests
from datetime import datetime

# %%
# TO CONVERT AIRPORT NAME TO ICAO CODE TO PASS IN TO THE API
airport_df = pd.read_csv('iata-icao.csv')
airport_df['airport'] = airport_df['airport'].str.upper()
print(airport_df.to_string())
# Out:
#      country_code                                region_name iata  icao                                                                              airport    latitude   longitude
# 0              AE                               Ash Shariqah  SHJ  OMSJ                                                        SHARJAH INTERNATIONAL AIRPORT   25.328600   55.517200
# 1              AE                                   Abu Zaby  AZI  OMAD                                                          AL BATEEN EXECUTIVE AIRPORT   24.428300   54.458100
# 2              AE                                Al Fujayrah  FJR  OMFJ                                                       FUJAIRAH INTERNATIONAL AIRPORT   25.112200   56.324000
# 3              AE                                   Abu Zaby  XSB  OMBY                                                                 SIR BANI YAS AIRPORT   24.283600   52.580300
# ...

# %%
arrAirport = input('Enter Arrival Aiport Code (ICAO - 4 Letter) :')
arrAirport = arrAirport.upper()

arrAirportIcao = ''

for airport in airport_df.itertuples():
    if(airport[5] == arrAirport):
        arrAirportIcao = airport[4]
        break

print(arrAirportIcao)
# Out:
# OMDB

# %%
#AREA EXTENT COORDINATE WGS4
lon_min,lat_min=-125.974,30.038
lon_max,lat_max=-68.748,52.214

#arrAirport = input('Enter Arrival Aiport Code (ICAO - 4 Letter) :')
#arrAirport = arrAirport.upper()

#REST API QUERY
user_name=''
password=''
#url_data='https://'+user_name+':'+password+'@opensky-network.org/api/states/all?'+'lamin='+str(lat_min)+'&lomin='+str(lon_min)+'&lamax='+str(lat_max)+'&lomax='+str(lon_max)
#url_data='https://opensky-network.org/api/flights/aircraft?icao24=uae531&begin=1517184000&end=1517270400'
url_data='https://opensky-network.org/api/flights/arrival?airport='+arrAirportIcao+'&begin=1689249601&end=1689343200'
#url_data='https://opensky-network.org/api/flights/arrival?airport=OMDB&begin=1689249601&end=1689343200'

print('From:')
print(datetime.fromtimestamp(1689249601))
print('To: ')
print(datetime.fromtimestamp(1689343200))
response=requests.get(url_data).json()
response
# Out:
# From:
# 2023-07-13 16:00:01
# To:
# 2023-07-14 18:00:00
# [{'icao24': '76cd09',
#   'firstSeen': 1689320491,
#   'estDepartureAirport': 'WSAC',
#   'lastSeen': 1689343166,
#   'estArrivalAirport': 'OMDB',
#   'callsign': 'SIA494  ',
#   'estDepartureAirportHorizDistance': 1956,
#   'estDepartureAirportVertDistance': 145,
#   'estArrivalAirportHorizDistance': 13328,
#   'estArrivalAirportVertDistance': 613,
#   'departureAirportCandidatesCount': 2,
#   'arrivalAirportCandidatesCount': 2},
#  {'icao24': '8003f0',
#   'firstSeen': 1689333966,
#   'estDepartureAirport': None,
#   'lastSeen': 1689342860,
#   'estArrivalAirport': 'OMDB',
#   'callsign': 'AXB191  ',
#   'estDepartureAirportHorizDistance': None,
#   'estDepartureAirportVertDistance': None,
#   'estArrivalAirportHorizDistance': 13089,
#   'estArrivalAirportVertDistance': 605,
#   'departureAirportCandidatesCount': 0,
#   'arrivalAirportCandidatesCount': 2},
#  {'icao24': '8963b1',
#   'firstSeen': 1689340458,
# ...

# %%
col_name=['icao24','first_seen','dep_airport','last_seen','arr_airport','call_sign']
flight_df=pd.DataFrame(response)
#test_df = flight_df
#test_df = test_df.dropna(subset=['estDepartureAirport'], inplace=True)
#test_df = test_df.dropna(subset=['estDepartureAirport'], inplace=True)
#test_df
flight_df.drop(columns=['estDepartureAirportHorizDistance','estDepartureAirportVertDistance','estArrivalAirportHorizDistance','estArrivalAirportVertDistance','departureAirportCandidatesCount','arrivalAirportCandidatesCount'], axis=1, inplace=True)

flight_df.dropna(inplace=True)
flight_df
# Out:
#      icao24   firstSeen estDepartureAirport    lastSeen estArrivalAirport  \
# 0    76cd09  1689320491                WSAC  1689343166              OMDB
# 3    7582f5  1689313935                RPLL  1689342620              OMDB
# 4    896455  1689293542                KSEA  1689342477              OMDB
# 5    800bc7  1689325146                VIDP  1689342203              OMDB
# 6    706068  1689337429                OKBK  1689342089              OMDB
# 9    8015c1  1689303129                WSAC  1689341847              OMDB
# 15   896195  1689310398                OMDB  1689341185              OMDB
# 19   706202  1689335116                OKBK  1689339850              OMDB
# 21   89617f  1689329681                LLBG  1689339506              OMDB
# 40   761487  1689325516                OPMT  1689334377              OMDB
# 43   801460  1689322399                VILK  1689334013              OMDB
# 49   896517  1689322306                LLBG  1689332873              OMDB
# ...

# %%
depAirport = input('Enter Departure Aiport Code (ICAO - 4 Letter) :')
depAirport = depAirport.upper()

depAirportIcao = ''

for airport in airport_df.itertuples():
    if(airport[5] == depAirport):
        depAirportIcao = airport[4]
        break

print(depAirportIcao)
# Out:
# OBBI

# %%
for i in flight_df.itertuples():
    if i[3] == depAirportIcao:
        print('The flight code is :'+i[1])
        takeoff = datetime.fromtimestamp(i[2])
        print('Takeoff Date and Time :')
        print(takeoff)
        landing = datetime.fromtimestamp(i[4])
        print('Landing Date and Time :')
        print(landing)
        print('Duration :')
        print(landing-takeoff)
# Out:
# The flight code is :8940d1
# Takeoff Date and Time :
# 2023-07-14 07:17:46
# Landing Date and Time :
# 2023-07-14 08:07:45
# Duration :
# 0:49:59
# The flight code is :8960d2
# Takeoff Date and Time :
# 2023-07-14 04:49:50
# Landing Date and Time :
# 2023-07-14 05:52:42
# Duration :
# 1:02:52
